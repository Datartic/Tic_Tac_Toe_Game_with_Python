# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
# Replace with your SQL Server connection details
server = 'localhost'  # IP address and port of the Docker container
database = 'AdventureWorksDW2019_Dimension'
username = 'sa'
password = 'reallyStrongPwd123'

# %%
conn_str = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"

# Create an engine
engine = create_engine(conn_str)

# %%
# Connect to the database
connection = engine.connect()
print(connection)
# Out:
# <sqlalchemy.engine.base.Connection object at 0x10fc3bd60>

# %%
query = 'SELECT * FROM AdventureWorksDW2019_Dimension.dbo.AdventureWorksDWBuildVersion'
df = pd.read_sql(query, engine)

print(df.head(5))
# Out:
#        DBVersion             VersionDate
# 0  14.0.1000.169 2017-08-22 19:39:35.643

# %%
# Read the data from SQL Server into a DataFrame back again
with engine.connect() as connection:
    query = f"SELECT * FROM dbo.DimAccount"
    raw_data_to_be_transformed = pd.read_sql_query(query, connection)

# %%
raw_data_to_be_transformed
# Out:
#     AccountKey  ParentAccountKey  AccountCodeAlternateKey  \
# 0            1               NaN                        1
# 1            2               1.0                       10
# 2            3               2.0                      110
# 3            4               3.0                     1110
# 4            5               3.0                     1120
# ..         ...               ...                      ...
# 94          97              95.0                     9520
# 95          98              95.0                     9530
# 96          99              95.0                     9540
# 97         100              27.0                     2220
# 98         101              51.0                     4200
#
#     ParentAccountCodeAlternateKey                      AccountDescription  \
# 0                             NaN                           Balance Sheet
# 1                             1.0                                  Assets
# 2                            10.0                          Current Assets
# 3                           110.0                                    Cash
# 4                           110.0                             Receivables
# ..                            ...                                     ...
# 94                         9500.0                                   Units
# 95                         9500.0                      Average Unit Price
# 96                         9500.0                          Square Footage
# 97                         2200.0  Current Installments of Long-term Debt
# 98                         4110.0                             Trade Sales
#
#     AccountType Operator                                      CustomMembers  \
# 0          None        ~                                               None
# 1        Assets        +                                               None
# 2        Assets        +                                               None
# 3        Assets        +                                               None
# 4        Assets        +                                               None
# ..          ...      ...                                                ...
# 94         Flow        ~                                               None
# 95     Balances        ~  [Account].[Accounts].[Account Level 04].&[50]/...
# 96     Balances        ~                                               None
# 97  Liabilities        +                                               None
# 98      Revenue        +                                               None
#
#    ValueType CustomMemberOptions
# 0   Currency                None
# 1   Currency                None
# 2   Currency                None
# 3   Currency                None
# 4   Currency                None
# ..       ...                 ...
# 94     Units                None
# 95  Currency                None
# 96     Units                None
# 97  Currency                None
# 98  Currency                None
#
# [99 rows x 10 columns]
